# %%
import pandas as pd

# %%
train_df = pd.read_csv("AllData.csv")
test_df = pd.read_csv("TestDataset.csv")

# %%
df
# Out:
#                     date  product_cost description   product_name  \
# 0    2024-02-17 08:37:29       2360.17  ингрид_282  название_1210
# 1    2024-02-22 03:45:14        894.36  ингрид_316  название_1778
# 2    2024-02-15 23:18:19       4788.19  ингрид_498   название_953
# 3    2024-09-06 04:18:10        470.64  ингрид_468   название_594
# 4    2024-04-09 13:08:26       4626.74  ингрид_277  название_1713
# ...                  ...           ...         ...            ...
# 9995 2024-05-27 07:06:34       2037.28  ингрид_372    название_66
# 9996 2024-01-01 06:41:52       2404.66   ингрид_64  название_1353
# 9997 2024-12-19 07:42:47        775.31   ингрид_25  название_1046
# 9998 2024-03-18 02:25:22       1139.44  ингрид_109   название_293
# 9999 2024-11-14 03:34:55       3918.31  ингрид_229   название_906
#
#      product_category  call_if_out_of_stock  leave_at_door_and_call  \
# 0         category_49                     1                       0
# ...

# %%
# Проверка загрузки данных
print(train_df.info())
print(train_df.head().to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142609 entries, 0 to 142608
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   AD_ID          142609 non-null  int64
#  1    CPM           142609 non-null  float64
#  2    VIEWS         142609 non-null  int64
#  3    CLICKS        142609 non-null  int64
#  4    ACTIONS       142609 non-null  int64
#  5    CHANNEL_NAME  142609 non-null  object
#  6    DATE          142609 non-null  object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 7.6+ MB
# None
# |    |   AD_ID |    CPM |    VIEWS |    CLICKS |    ACTIONS |  CHANNEL_NAME            |  DATE      |
# |---:|--------:|-------:|---------:|----------:|-----------:|:-------------------------|:-----------|
# |  0 |    3652 |    1.2 |       52 |         0 |          0 | tanya_in_france          | 2024-10-02 |
# ...

# %%
print(test_df.info())
print(test_df.head().to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22557 entries, 0 to 22556
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CPM           22557 non-null  float64
#  1   CHANNEL_NAME  22557 non-null  object
#  2   DATE          22557 non-null  object
#  3   VIEWS         0 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 705.0+ KB
# None
# |    |   CPM | CHANNEL_NAME     | DATE       |   VIEWS |
# |---:|------:|:-----------------|:-----------|--------:|
# |  0 |  5    | A117_SportMotion | 2025-10-24 |     nan |
# |  1 | 15    | A1BOUTIQUE       | 2025-11-04 |     nan |
# |  2 |  8    | A1BOUTIQUE       | 2025-12-01 |     nan |
# |  3 |  4.81 | A4omg            | 2025-10-08 |     nan |
# |  4 |  2.5  | ABTOvaib         | 2025-12-09 |     nan |
